# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("F:\Mission2024\data_analysis\matplotlib\Bank Customer Churn Prediction.csv")
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
plt.style.use("default")

#plt.scatter(df['age'],df['balance'],alpha=0.3)
df.plot.scatter(x = 'age', y = "balance",c='y',)
plt.title("scatter plot")
plt.xlabel('age')
plt.ylabel("balence")
# Out:
# Text(0, 0.5, 'balence')

# %%
## analysis :


## maximum concentration of data is between ~22-55
## max balence is at age ~35-40
## min balence is present at all ages

# %%
## in this case i cosnsidered age less than 90

data=df['age']<90
df1=df[data]
plt.scatter(df1['age'],df1['balance'],color='g')

# %%
# check the age distribution
plt.hist(df['age'])
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df['country'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
g=df.groupby('country').count()['churn']
g
# Out:
# country
# France     5014
# Germany    2509
# Spain      2477
# Name: churn, dtype: int64
