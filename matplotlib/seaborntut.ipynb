# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data=sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(data['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(data['total_bill'],kde=True)
# Out:
# C:\Users\Vaishnavi\AppData\Local\Temp\ipykernel_9752\3051038451.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['total_bill'],kde=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(x=data['total_bill'],y=data['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
g=data.groupby('smoker')
g.count()['total_bill']
# Out:
# smoker
# Yes     93
# No     151
# Name: total_bill, dtype: int64

# %%
sns.relplot(data=data,x=data['total_bill'],y=data['tip'],hue=data['smoker'])

# %%
sns.scatterplot(data=data,x=data['total_bill'],y=data['tip'],hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data,x=data['total_bill'],y=data['tip'],hue=data['size'])

# %%
sns.relplot(data,x=data['total_bill'],y=data['tip'],style=data['smoker'])

# %%
sns.relplot(data,x=data['total_bill'],y=data['tip'],hue=data['time'],style=data['smoker'])

# %%
data[['day','total_bill']]
# Out:
#       day  total_bill
# 0     Sun       16.99
# 1     Sun       10.34
# 2     Sun       21.01
# 3     Sun       23.68
# 4     Sun       24.59
# ..    ...         ...
# 239   Sat       29.03
# 240   Sat       27.18
# 241   Sat       22.67
# 242   Sat       17.82
# 243  Thur       18.78
#
# [244 rows x 2 columns]

# %%
sns.scatterplot(data=data,x=data['tip'],y=data['total_bill'],hue=data['time'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
g=data.groupby(data['day'])
g.count()['total_bill']
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: total_bill, dtype: int64

# %%
sns.barplot(data=data,y=data['total_bill'],x=data['day'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.catplot(data=data,y=data['total_bill'],x=data['day'])

# %%
sns.jointplot(data=data,x=data['total_bill'],y=data['tip'],kind='reg')

# %%
sns.regplot(data=data,x=data['total_bill'],y=data['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(data=data,x=data['total_bill'],y=data['tip'],kind='kde') ## contour plot 
### important ### used in metrological dept

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue='smoker',palette='coolwarm')

# %%
## box plot : give the outliers for the 
sns.boxplot(data=data,y=data['day'],x=data['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(data=data, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
data.corr()
# Out:
# C:\Users\Vaishnavi\AppData\Local\Temp\ipykernel_9752\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
datar = data[['total_bill', 'tip', 'size']]
datar.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(datar.corr(), annot = True, cmap = 'rainbow')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'sex', data=data)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.catplot(x = 'day', y = 'tip', data = data, kind='swarm')
# Out:
# F:\Anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
